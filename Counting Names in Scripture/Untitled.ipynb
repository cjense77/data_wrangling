# %%
import pandas as pd

scriptures = pd.read_csv("scriptures.csv")

# %%
results = pd.DataFrame(columns=["Reference", "Verse"])
# Out:
# Empty DataFrame
# Columns: [Reference, Verse]
# Index: []

# %%
results = scriptures[scriptures.scripture_text.str.contains("child")]
results[['scripture_text']]
# Out:
#                                           scripture_text
# 71     Unto the woman he said, I will greatly multipl...
# 141    There were giants in the earth in those days; ...
# 255    Unto Shem also, the father of all the children...
# 256    The children of Shem; Elam, and Asshur, and Ar...
# 257    And the children of Aram; Uz, and Hul, and Get...
# 271    And the LORD came down to see the city and the...
# 296              But Sarai was barren; she had no child.
# 362    And Abram said, Lord GOD, what wilt thou give ...
# 382    NOW Sarai Abram's wife bare him no children: a...
# 383    And Sarai said unto Abram, Behold now, the LOR...
# 392    And the angel of the LORD said unto her, Behol...
# 407    This is my covenant, which ye shall keep, betw...
# 409    And he that is eight days old shall be circumc...
# 411    And the uncircumcised man child whose flesh of...
# 414    Then Abraham fell upon his face, and laughed, ...
# ...

# %%
len(results)
# Out:
# 7422
